# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
def openImageToNumpy(path, format='RGB'):
    img = Image.open(path).convert(format)
    return np.array(img).astype(np.uint8)

# %%
def gausianPiramid(img,levels):
    lower = img.copy()
    gaussian_pyr = [lower]
    for i in range(levels):
        lower = cv2.pyrDown(lower)
        gaussian_pyr.append(lower)
    return gaussian_pyr

def plotPiramid(piramid):
    size = 0
    for i in range(len(piramid)):
        size = np.array(size) + np.array(piramid[i].shape)
    size[-1] = piramid[0].shape[-1]
    img2 = np.zeros(size, dtype=np.uint8)
    x =0
    for i in range(len(piramid)):
        img2[x:x+piramid[i].shape[0],x:x+piramid[i].shape[1],:] = piramid[i]
        x += piramid[i].shape[0]
    return img2

# %%
def reshapeImageToNextOdd(img):
    shape = img.shape
    if img.shape[0]%2!= 0:
        shape = (shape[1],shape[0]+1)
    if img.shape[1]%2 != 0:
        shape = (shape[1]+1,shape[0])    
    return cv2.resize(img, shape)

# %%
manzana = openImageToNumpy('manzana.png')

naranja = openImageToNumpy('orange.png')

print(manzana.shape)
print(naranja.shape)
plt.subplot(1,2,1)
plt.imshow(manzana)
plt.subplot(1,2,2)
plt.imshow(naranja)
# Out:
# (448, 624, 3)
# (448, 624, 3)

# %%
def gausianPiramid(img,levels):
    piramid = [img.copy()]
    shape =np.array( manzana.shape[:2])[::-1]
    for i in range(levels):
        piramid.append(cv2.resize(img,shape//2**i))
    return piramid

# %%
def lapacePiramid(gaussian_pyr):
    piramid = []    
    levels = len(gaussian_pyr)
    for i in range(levels-1,0,-1):
        shape =np.array(gaussian_pyr[i-1].shape[:2])[::-1]
        GE = cv2.resize(gaussian_pyr[i],shape)
        N = cv2.subtract(gaussian_pyr[i-1],GE)
        plt.imshow(N)
        plt.show()
        piramid.append(N)
    return piramid

# %%
gp = gausianPiramid(manzana,6)
lp = lapacePiramid(gp)
plt.imshow(plotPiramid(lp))

# %%
def getkernel2(size=11, s=3.0):
    def gaussian_kernel(x, sigma=1.0):
        return np.exp(-x*2/(2*sigma*2))

    kernel = np.zeros((size, size), dtype=np.float32)
    centerx, centery = size // 2, size // 2
    for i in range(size):
        for j in range(size):
            dist_center = np.sqrt((i - centerx)**2 + (j - centery)**2)
            kernel[i, j] = dist_center

    kernel2 = gaussian_kernel(kernel, sigma=s)
    return kernel2

# %%
def create_circular_mask(h, w, center=None, radius=None):

    if center is None: # use the middle of the image
        center = (int(w/2), int(h/2))
    if radius is None: # use the smallest distance between the center and image walls
        radius = min(center[0], center[1], w-center[0], h-center[1])

    Y, X = np.ogrid[:h, :w]
    dist_from_center = np.sqrt((X - center[0])**2 + (Y-center[1])**2)

    mask = dist_from_center <= radius
    return mask

# %%
mask = create_circular_mask(manzana.shape[0],manzana.shape[1])
mask = np.stack([mask,mask,mask],axis=-1)
# apply the mask to the image and show the result

masked = np.where(mask,manzana,naranja)
plt.imshow(masked)

# %%
import cv2 as cv
import numpy as np,sys
A = cv.imread('ojo.jpg')
A = cv.cvtColor(A,cv.COLOR_BGR2RGB)
A = cv.resize(A,(512,512))
B = cv.imread('mano.jpg')
B = cv.cvtColor(B,cv.COLOR_BGR2RGB)
B = cv.resize(B,(512,512))

mask = create_circular_mask(A.shape[0],A.shape[1],radius=100)
mask = np.stack([mask,mask,mask],axis=-1)
# apply the mask to the image and show the result

A = np.where(mask,A,0)
B = np.where(mask,0,B)

# generate Gaussian pyramid for
#  A
levels = 3
G = A.copy()
gpA = [G]
for i in range(6):
    G = cv.pyrDown(G)
    gpA.append(G)
# generate Gaussian pyramid for B
G = B.copy()
gpB = [G]
for i in range(6):
    G = cv.pyrDown(G)
    gpB.append(G)
# generate Laplacian Pyramid for A
lpA = [gpA[levels]]
for i in range(levels,0,-1):
    GE = cv.pyrUp(gpA[i])
    L = cv.subtract(gpA[i-1],GE)
    lpA.append(L)
# generate Laplacian Pyramid for B
lpB = [gpB[levels]]
for i in range(levels,0,-1):
    GE = cv.pyrUp(gpB[i])
    L = cv.subtract(gpB[i-1],GE)
    lpB.append(L)
# Now add left and right halves of images in each level
LS = []
for la,lb in zip(lpA,lpB):
    rows,cols,dpt = la.shape      
  #  ls = la*kernel + lb*(kernel)
    #plt.imshow(ls)
   # plt.show()
    #ls = np.hstack((la[:,0:cols//2], lb[:,cols//2:]))
    #mask = create_circular_mask(rows,cols,radius=rows//8)
    #mask = np.stack([mask,mask,mask],axis=-1)
    #
    #ls = np.where(mask,la,lb)       
    LS.append(la+lb)
# now reconstruct
ls_ = LS[0]
for i in range(1,levels+1):
    ls_ = cv.pyrUp(ls_)
    ls_ = cv.add(ls_, LS[i])
# image with direct connecting each half
real = np.hstack((A[:,:cols//2],B[:,cols//2:]))

#print(set(ls_.flatten()))
plt.subplot(1,2,1)
plt.imshow(ls_ )
plt.subplot(1,2,2)
plt.imshow(real)

# %%
kernel = getkernel2(size=60, s=13.0)
plt.imshow(kernel,cmap='gray')
